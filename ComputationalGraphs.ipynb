# %% [markdown]
# # Auto Grad and Computational Graphs
#
# Computational Graphs are an effective mechanism for implementing Backprop!! This idea of Computational

# %%
from custom_autograd import Variable

# %%
x = Variable(5)
y = Variable(3)

z = x + y
w = x.sin()

l = z - w

# %%
l.backward()

# %%
x.grad, y.grad, z.grad, w.grad, l.grad
# Out:
# (np.float64(0.7163378145367738),
#  np.float16(1.0),
#  np.float16(1.0),
#  np.float16(-1.0),
#  np.float16(1.0))

# %% [markdown]
# Sanity Checking if our code is correct:
# $
# \frac{\partial l}{\partial x} = 1 - cos(x)
# $

# %%
import numpy as np

1 - np.cos(5)  # x.grad
# Out:
# np.float64(0.7163378145367738)

# %%
from custom_vector_autograd import CustomTensorVariable

# %%
class Model:
    def __init__(self):
        self.layer1 = CustomTensorVariable(np.random.rand(10, 10).astype(np.float16))
        self.bias1 = CustomTensorVariable(np.random.rand(10, 1).astype(np.float16))
        self.layer2 = CustomTensorVariable(np.random.rand(1,  10).astype(np.float16))
        self.bias2 = CustomTensorVariable(np.random.rand(1, 1).astype(np.float16))

    def forward(self, x:CustomTensorVariable):
        out1 = self.layer1.matmul(x) + self.bias1
        print(out1.value.shape)
        out2 = self.layer2.matmul(out1) + self.bias2
        return out2

our_model = Model()

# %%
x = np.random.rand(10, 1).astype(np.float16)

pred = our_model.forward(x)
# Out:
# (10, 1)

# %%
pred.value
# Out:
# array([[11.08]], dtype=float16)

# %%
loss = (pred - np.random.rand(1).astype(np.float16))

# %%
loss.backward()

# %%
our_model.layer1.grad
# Out:
# array([[6.7676e-01, 1.9543e-01, 3.4912e-01, 4.0479e-01, 5.9229e-01,
#         1.6748e-01, 1.8640e-01, 1.8112e-02, 4.9316e-01, 4.6899e-01],
#        [1.1652e-01, 3.3661e-02, 6.0120e-02, 6.9702e-02, 1.0199e-01,
#         2.8839e-02, 3.2104e-02, 3.1185e-03, 8.4900e-02, 8.0750e-02],
#        [7.5989e-03, 2.1935e-03, 3.9177e-03, 4.5433e-03, 6.6490e-03,
#         1.8797e-03, 2.0924e-03, 2.0337e-04, 5.5351e-03, 5.2643e-03],
#        [5.5957e-01, 1.6162e-01, 2.8882e-01, 3.3472e-01, 4.8975e-01,
#         1.3855e-01, 1.5417e-01, 1.4984e-02, 4.0796e-01, 3.8794e-01],
#        [2.8735e-01, 8.2947e-02, 1.4819e-01, 1.7188e-01, 2.5146e-01,
#         7.1106e-02, 7.9102e-02, 7.6904e-03, 2.0935e-01, 1.9910e-01],
#        [8.0762e-01, 2.3315e-01, 4.1650e-01, 4.8315e-01, 7.0654e-01,
#         1.9983e-01, 2.2241e-01, 2.1622e-02, 5.8838e-01, 5.5957e-01],
#        [5.7324e-01, 1.6553e-01, 2.9590e-01, 3.4302e-01, 5.0146e-01,
#         1.4185e-01, 1.5796e-01, 1.5350e-02, 4.1797e-01, 3.9746e-01],
#        [1.6968e-01, 4.9011e-02, 8.7585e-02, 1.0150e-01, 1.4856e-01,
#         4.1992e-02, 4.6753e-02, 4.5433e-03, 1.2372e-01, 1.1761e-01],
#        [5.3284e-02, 1.5388e-02, 2.7496e-02, 3.1891e-02, 4.6631e-02,
#         1.3191e-02, 1.4679e-02, 1.4267e-03, 3.8849e-02, 3.6926e-02],
#        [1.2976e-01, 3.7476e-02, 6.6956e-02, 7.7637e-02, 1.1353e-01,
#         3.2104e-02, 3.5736e-02, 3.4733e-03, 9.4604e-02, 8.9966e-02]],
#       dtype=float16)
